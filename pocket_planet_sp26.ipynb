# %% [markdown]
# # Pocket Planet
#
# ## Introduction
# #### Authors:
# v1.0 (2020 Spring) Alexander Khazatsky, William Gan, Kannan Ramchandran
#
#
# v2.0 (2023 Spring) Andy Dong
#
# v3.0 (2025 Fall) Arjun Banerjee, Kailash Ranganathan
#
# In this lab, we'll build a world using probability! To do so, we will set up a world and treat plants as particles. At each time step, these plants will reproduce and compete with each other for the limited space, in the process passing on the fitter genes.
#
# Below is an example of such a simulation we will build.
#
# <div>
#   <table>
#     <tr>
#       <td>
#         <img src="images/cover_photo.png" width="400"/>
#       </td>
#     </tr>
#   </table>
# </div>

# %%
# If modules have not been installed yet:
#It is reccomeded to run your notebook in a seperate virtual environment, either conda or venv

# %pip install -r requirements.txt

# Restart kernel afterwards, if needed
# Out:
# Requirement already satisfied: numpy in c:\users\benja\anaconda3\lib\site-packages (from -r requirements.txt (line 1)) (1.26.4)
# Requirement already satisfied: matplotlib in c:\users\benja\anaconda3\lib\site-packages (from -r requirements.txt (line 2)) (3.8.0)
# Requirement already satisfied: scipy in c:\users\benja\anaconda3\lib\site-packages (from -r requirements.txt (line 3)) (1.11.4)
# Requirement already satisfied: otter-grader==6.1.0 in c:\users\benja\anaconda3\lib\site-packages (from -r requirements.txt (line 4)) (6.1.0)
# Requirement already satisfied: click<9.0.0,>=8.1.7 in c:\users\benja\anaconda3\lib\site-packages (from otter-grader==6.1.0->-r requirements.txt (line 4)) (8.1.7)
# Requirement already satisfied: dill>=0.3.0 in c:\users\benja\anaconda3\lib\site-packages (from otter-grader==6.1.0->-r requirements.txt (line 4)) (0.3.7)
# Requirement already satisfied: fica>=0.4.1 in c:\users\benja\anaconda3\lib\site-packages (from otter-grader==6.1.0->-r requirements.txt (line 4)) (0.4.1)
# Requirement already satisfied: ipylab<2.0.0,>=1.0.0 in c:\users\benja\anaconda3\lib\site-packages (from otter-grader==6.1.0->-r requirements.txt (line 4)) (1.1.0)
# Requirement already satisfied: ipython in c:\users\benja\anaconda3\lib\site-packages (from otter-grader==6.1.0->-r requirements.txt (line 4)) (8.20.0)
# Requirement already satisfied: ipywidgets<9.0.0,>=8.1.5 in c:\users\benja\anaconda3\lib\site-packages (from otter-grader==6.1.0->-r requirements.txt (line 4)) (8.1.8)
# Requirement already satisfied: jinja2<4.0,>=3.1 in c:\users\benja\anaconda3\lib\site-packages (from otter-grader==6.1.0->-r requirements.txt (line 4)) (3.1.3)
# Requirement already satisfied: jupytext<2.0.0,>=1.16.4 in c:\users\benja\anaconda3\lib\site-packages (from otter-grader==6.1.0->-r requirements.txt (line 4)) (1.19.1)
# Requirement already satisfied: nbconvert>=6.0.0 in c:\users\benja\anaconda3\lib\site-packages (from nbconvert[webpdf]>=6.0.0; sys_platform != "emscripten" and sys_platform != "wasi"->otter-grader==6.1.0->-r requirements.txt (line 4)) (7.10.0)
# Requirement already satisfied: nbformat>=5.0.0 in c:\users\benja\anaconda3\lib\site-packages (from otter-grader==6.1.0->-r requirements.txt (line 4)) (5.9.2)
# Requirement already satisfied: pandas>=2.0.0 in c:\users\benja\anaconda3\lib\site-packages (from otter-grader==6.1.0->-r requirements.txt (line 4)) (2.1.4)
# Requirement already satisfied: python-on-whales<1.0.0,>=0.72.0 in c:\users\benja\anaconda3\lib\site-packages (from otter-grader==6.1.0->-r requirements.txt (line 4)) (0.80.0)
# Requirement already satisfied: pyyaml<7,>=6 in c:\users\benja\anaconda3\lib\site-packages (from otter-grader==6.1.0->-r requirements.txt (line 4)) (6.0.1)
# Requirement already satisfied: requests<3.0,>=2.31 in c:\users\benja\anaconda3\lib\site-packages (from otter-grader==6.1.0->-r requirements.txt (line 4)) (2.31.0)
# Requirement already satisfied: wrapt<2.0.0,>=1.16.0 in c:\users\benja\anaconda3\lib\site-packages (from otter-grader==6.1.0->-r requirements.txt (line 4)) (1.17.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\benja\anaconda3\lib\site-packages (from matplotlib->-r requirements.txt (line 2)) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\benja\anaconda3\lib\site-packages (from matplotlib->-r requirements.txt (line 2)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\benja\anaconda3\lib\site-packages (from matplotlib->-r requirements.txt (line 2)) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\benja\anaconda3\lib\site-packages (from matplotlib->-r requirements.txt (line 2)) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\benja\anaconda3\lib\site-packages (from matplotlib->-r requirements.txt (line 2)) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\benja\anaconda3\lib\site-packages (from matplotlib->-r requirements.txt (line 2)) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\benja\anaconda3\lib\site-packages (from matplotlib->-r requirements.txt (line 2)) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\benja\anaconda3\lib\site-packages (from matplotlib->-r requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: colorama in c:\users\benja\anaconda3\lib\site-packages (from click<9.0.0,>=8.1.7->otter-grader==6.1.0->-r requirements.txt (line 4)) (0.4.6)
# Requirement already satisfied: docutils in c:\users\benja\anaconda3\lib\site-packages (from fica>=0.4.1->otter-grader==6.1.0->-r requirements.txt (line 4)) (0.18.1)
# Requirement already satisfied: sphinx in c:\users\benja\anaconda3\lib\site-packages (from fica>=0.4.1->otter-grader==6.1.0->-r requirements.txt (line 4)) (5.0.2)
# Requirement already satisfied: comm>=0.1.3 in c:\users\benja\anaconda3\lib\site-packages (from ipywidgets<9.0.0,>=8.1.5->otter-grader==6.1.0->-r requirements.txt (line 4)) (0.2.3)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\benja\anaconda3\lib\site-packages (from ipywidgets<9.0.0,>=8.1.5->otter-grader==6.1.0->-r requirements.txt (line 4)) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\benja\anaconda3\lib\site-packages (from ipywidgets<9.0.0,>=8.1.5->otter-grader==6.1.0->-r requirements.txt (line 4)) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\benja\anaconda3\lib\site-packages (from ipywidgets<9.0.0,>=8.1.5->otter-grader==6.1.0->-r requirements.txt (line 4)) (3.0.16)
# Requirement already satisfied: decorator in c:\users\benja\anaconda3\lib\site-packages (from ipython->otter-grader==6.1.0->-r requirements.txt (line 4)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\benja\anaconda3\lib\site-packages (from ipython->otter-grader==6.1.0->-r requirements.txt (line 4)) (0.18.1)
# Requirement already satisfied: matplotlib-inline in c:\users\benja\anaconda3\lib\site-packages (from ipython->otter-grader==6.1.0->-r requirements.txt (line 4)) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\benja\anaconda3\lib\site-packages (from ipython->otter-grader==6.1.0->-r requirements.txt (line 4)) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\benja\anaconda3\lib\site-packages (from ipython->otter-grader==6.1.0->-r requirements.txt (line 4)) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\benja\anaconda3\lib\site-packages (from ipython->otter-grader==6.1.0->-r requirements.txt (line 4)) (0.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\benja\anaconda3\lib\site-packages (from jinja2<4.0,>=3.1->otter-grader==6.1.0->-r requirements.txt (line 4)) (2.1.3)
# Requirement already satisfied: markdown-it-py>=1.0 in c:\users\benja\anaconda3\lib\site-packages (from jupytext<2.0.0,>=1.16.4->otter-grader==6.1.0->-r requirements.txt (line 4)) (2.2.0)
# Requirement already satisfied: mdit-py-plugins in c:\users\benja\anaconda3\lib\site-packages (from jupytext<2.0.0,>=1.16.4->otter-grader==6.1.0->-r requirements.txt (line 4)) (0.3.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\benja\anaconda3\lib\site-packages (from nbconvert>=6.0.0->nbconvert[webpdf]>=6.0.0; sys_platform != "emscripten" and sys_platform != "wasi"->otter-grader==6.1.0->-r requirements.txt (line 4)) (4.12.2)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\benja\anaconda3\lib\site-packages (from nbconvert>=6.0.0->nbconvert[webpdf]>=6.0.0; sys_platform != "emscripten" and sys_platform != "wasi"->otter-grader==6.1.0->-r requirements.txt (line 4)) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\benja\anaconda3\lib\site-packages (from nbconvert>=6.0.0->nbconvert[webpdf]>=6.0.0; sys_platform != "emscripten" and sys_platform != "wasi"->otter-grader==6.1.0->-r requirements.txt (line 4)) (0.7.1)
# Requirement already satisfied: jupyter-core>=4.7 in c:\users\benja\anaconda3\lib\site-packages (from nbconvert>=6.0.0->nbconvert[webpdf]>=6.0.0; sys_platform != "emscripten" and sys_platform != "wasi"->otter-grader==6.1.0->-r requirements.txt (line 4)) (5.5.0)
# Requirement already satisfied: jupyterlab-pygments in c:\users\benja\anaconda3\lib\site-packages (from nbconvert>=6.0.0->nbconvert[webpdf]>=6.0.0; sys_platform != "emscripten" and sys_platform != "wasi"->otter-grader==6.1.0->-r requirements.txt (line 4)) (0.1.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\benja\anaconda3\lib\site-packages (from nbconvert>=6.0.0->nbconvert[webpdf]>=6.0.0; sys_platform != "emscripten" and sys_platform != "wasi"->otter-grader==6.1.0->-r requirements.txt (line 4)) (2.0.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\benja\anaconda3\lib\site-packages (from nbconvert>=6.0.0->nbconvert[webpdf]>=6.0.0; sys_platform != "emscripten" and sys_platform != "wasi"->otter-grader==6.1.0->-r requirements.txt (line 4)) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\benja\anaconda3\lib\site-packages (from nbconvert>=6.0.0->nbconvert[webpdf]>=6.0.0; sys_platform != "emscripten" and sys_platform != "wasi"->otter-grader==6.1.0->-r requirements.txt (line 4)) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\users\benja\anaconda3\lib\site-packages (from nbconvert>=6.0.0->nbconvert[webpdf]>=6.0.0; sys_platform != "emscripten" and sys_platform != "wasi"->otter-grader==6.1.0->-r requirements.txt (line 4)) (1.2.1)
# Requirement already satisfied: playwright in c:\users\benja\anaconda3\lib\site-packages (from nbconvert[webpdf]>=6.0.0; sys_platform != "emscripten" and sys_platform != "wasi"->otter-grader==6.1.0->-r requirements.txt (line 4)) (1.58.0)
# Requirement already satisfied: fastjsonschema in c:\users\benja\anaconda3\lib\site-packages (from nbformat>=5.0.0->otter-grader==6.1.0->-r requirements.txt (line 4)) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\benja\anaconda3\lib\site-packages (from nbformat>=5.0.0->otter-grader==6.1.0->-r requirements.txt (line 4)) (4.19.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\benja\anaconda3\lib\site-packages (from pandas>=2.0.0->otter-grader==6.1.0->-r requirements.txt (line 4)) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\benja\anaconda3\lib\site-packages (from pandas>=2.0.0->otter-grader==6.1.0->-r requirements.txt (line 4)) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\benja\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->-r requirements.txt (line 2)) (1.16.0)
# Requirement already satisfied: pydantic!=2.0.*,<3,>=2 in c:\users\benja\anaconda3\lib\site-packages (from python-on-whales<1.0.0,>=0.72.0->otter-grader==6.1.0->-r requirements.txt (line 4)) (2.12.5)
# Requirement already satisfied: typing-extensions in c:\users\benja\anaconda3\lib\site-packages (from python-on-whales<1.0.0,>=0.72.0->otter-grader==6.1.0->-r requirements.txt (line 4)) (4.15.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\benja\anaconda3\lib\site-packages (from requests<3.0,>=2.31->otter-grader==6.1.0->-r requirements.txt (line 4)) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\benja\anaconda3\lib\site-packages (from requests<3.0,>=2.31->otter-grader==6.1.0->-r requirements.txt (line 4)) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\benja\anaconda3\lib\site-packages (from requests<3.0,>=2.31->otter-grader==6.1.0->-r requirements.txt (line 4)) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\benja\anaconda3\lib\site-packages (from requests<3.0,>=2.31->otter-grader==6.1.0->-r requirements.txt (line 4)) (2024.2.2)
# Requirement already satisfied: webencodings in c:\users\benja\anaconda3\lib\site-packages (from bleach!=5.0.0->nbconvert>=6.0.0->nbconvert[webpdf]>=6.0.0; sys_platform != "emscripten" and sys_platform != "wasi"->otter-grader==6.1.0->-r requirements.txt (line 4)) (0.5.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\benja\anaconda3\lib\site-packages (from jedi>=0.16->ipython->otter-grader==6.1.0->-r requirements.txt (line 4)) (0.8.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\benja\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=5.0.0->otter-grader==6.1.0->-r requirements.txt (line 4)) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\benja\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=5.0.0->otter-grader==6.1.0->-r requirements.txt (line 4)) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\benja\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=5.0.0->otter-grader==6.1.0->-r requirements.txt (line 4)) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\benja\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=5.0.0->otter-grader==6.1.0->-r requirements.txt (line 4)) (0.10.6)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\benja\anaconda3\lib\site-packages (from jupyter-core>=4.7->nbconvert>=6.0.0->nbconvert[webpdf]>=6.0.0; sys_platform != "emscripten" and sys_platform != "wasi"->otter-grader==6.1.0->-r requirements.txt (line 4)) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\benja\anaconda3\lib\site-packages (from jupyter-core>=4.7->nbconvert>=6.0.0->nbconvert[webpdf]>=6.0.0; sys_platform != "emscripten" and sys_platform != "wasi"->otter-grader==6.1.0->-r requirements.txt (line 4)) (305.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\benja\anaconda3\lib\site-packages (from markdown-it-py>=1.0->jupytext<2.0.0,>=1.16.4->otter-grader==6.1.0->-r requirements.txt (line 4)) (0.1.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\benja\anaconda3\lib\site-packages (from nbclient>=0.5.0->nbconvert>=6.0.0->nbconvert[webpdf]>=6.0.0; sys_platform != "emscripten" and sys_platform != "wasi"->otter-grader==6.1.0->-r requirements.txt (line 4)) (7.4.9)
# Requirement already satisfied: wcwidth in c:\users\benja\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython->otter-grader==6.1.0->-r requirements.txt (line 4)) (0.2.5)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\benja\anaconda3\lib\site-packages (from pydantic!=2.0.*,<3,>=2->python-on-whales<1.0.0,>=0.72.0->otter-grader==6.1.0->-r requirements.txt (line 4)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\benja\anaconda3\lib\site-packages (from pydantic!=2.0.*,<3,>=2->python-on-whales<1.0.0,>=0.72.0->otter-grader==6.1.0->-r requirements.txt (line 4)) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\benja\anaconda3\lib\site-packages (from pydantic!=2.0.*,<3,>=2->python-on-whales<1.0.0,>=0.72.0->otter-grader==6.1.0->-r requirements.txt (line 4)) (0.4.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\benja\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert>=6.0.0->nbconvert[webpdf]>=6.0.0; sys_platform != "emscripten" and sys_platform != "wasi"->otter-grader==6.1.0->-r requirements.txt (line 4)) (2.5)
# Requirement already satisfied: pyee<14,>=13 in c:\users\benja\anaconda3\lib\site-packages (from playwright->nbconvert[webpdf]>=6.0.0; sys_platform != "emscripten" and sys_platform != "wasi"->otter-grader==6.1.0->-r requirements.txt (line 4)) (13.0.0)
# Requirement already satisfied: greenlet<4.0.0,>=3.1.1 in c:\users\benja\anaconda3\lib\site-packages (from playwright->nbconvert[webpdf]>=6.0.0; sys_platform != "emscripten" and sys_platform != "wasi"->otter-grader==6.1.0->-r requirements.txt (line 4)) (3.3.1)
# Requirement already satisfied: sphinxcontrib-applehelp in c:\users\benja\anaconda3\lib\site-packages (from sphinx->fica>=0.4.1->otter-grader==6.1.0->-r requirements.txt (line 4)) (1.0.2)
# Requirement already satisfied: sphinxcontrib-devhelp in c:\users\benja\anaconda3\lib\site-packages (from sphinx->fica>=0.4.1->otter-grader==6.1.0->-r requirements.txt (line 4)) (1.0.2)
# Requirement already satisfied: sphinxcontrib-jsmath in c:\users\benja\anaconda3\lib\site-packages (from sphinx->fica>=0.4.1->otter-grader==6.1.0->-r requirements.txt (line 4)) (1.0.1)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.0 in c:\users\benja\anaconda3\lib\site-packages (from sphinx->fica>=0.4.1->otter-grader==6.1.0->-r requirements.txt (line 4)) (2.0.0)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.5 in c:\users\benja\anaconda3\lib\site-packages (from sphinx->fica>=0.4.1->otter-grader==6.1.0->-r requirements.txt (line 4)) (1.1.5)
# Requirement already satisfied: sphinxcontrib-qthelp in c:\users\benja\anaconda3\lib\site-packages (from sphinx->fica>=0.4.1->otter-grader==6.1.0->-r requirements.txt (line 4)) (1.0.3)
# Requirement already satisfied: snowballstemmer>=1.1 in c:\users\benja\anaconda3\lib\site-packages (from sphinx->fica>=0.4.1->otter-grader==6.1.0->-r requirements.txt (line 4)) (2.2.0)
# Requirement already satisfied: babel>=1.3 in c:\users\benja\anaconda3\lib\site-packages (from sphinx->fica>=0.4.1->otter-grader==6.1.0->-r requirements.txt (line 4)) (2.11.0)
# Requirement already satisfied: alabaster<0.8,>=0.7 in c:\users\benja\anaconda3\lib\site-packages (from sphinx->fica>=0.4.1->otter-grader==6.1.0->-r requirements.txt (line 4)) (0.7.12)
# Requirement already satisfied: imagesize in c:\users\benja\anaconda3\lib\site-packages (from sphinx->fica>=0.4.1->otter-grader==6.1.0->-r requirements.txt (line 4)) (1.4.1)
# Requirement already satisfied: executing in c:\users\benja\anaconda3\lib\site-packages (from stack-data->ipython->otter-grader==6.1.0->-r requirements.txt (line 4)) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\benja\anaconda3\lib\site-packages (from stack-data->ipython->otter-grader==6.1.0->-r requirements.txt (line 4)) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\benja\anaconda3\lib\site-packages (from stack-data->ipython->otter-grader==6.1.0->-r requirements.txt (line 4)) (0.2.2)
# Requirement already satisfied: entrypoints in c:\users\benja\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert>=6.0.0->nbconvert[webpdf]>=6.0.0; sys_platform != "emscripten" and sys_platform != "wasi"->otter-grader==6.1.0->-r requirements.txt (line 4)) (0.4)
# Requirement already satisfied: nest-asyncio>=1.5.4 in c:\users\benja\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert>=6.0.0->nbconvert[webpdf]>=6.0.0; sys_platform != "emscripten" and sys_platform != "wasi"->otter-grader==6.1.0->-r requirements.txt (line 4)) (1.6.0)
# Requirement already satisfied: pyzmq>=23.0 in c:\users\benja\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert>=6.0.0->nbconvert[webpdf]>=6.0.0; sys_platform != "emscripten" and sys_platform != "wasi"->otter-grader==6.1.0->-r requirements.txt (line 4)) (24.0.1)
# Requirement already satisfied: tornado>=6.2 in c:\users\benja\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert>=6.0.0->nbconvert[webpdf]>=6.0.0; sys_platform != "emscripten" and sys_platform != "wasi"->otter-grader==6.1.0->-r requirements.txt (line 4)) (6.3.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
from itertools import product
import numpy as np
import scipy
import os
import random

# %%
# %load_ext autoreload
# %autoreload 2
from pocket_planet_utils import *

# %% [markdown]
# ## Part 1: Generating the World
#
# The first step to our simulation is to build the world. But how do we generate elevations and lanscapes that look realistic?
#
# Let's first define our world. We will design our world to be a 100 pixel by 100 pixel square with 7 terrains: ocean, shallows, sand, dirt, inland, mountain, and snow. Each terrain will corresponds to an elevation range, and so to generate our world, we just need to generate 2-dimensional heigh coordinates. The following pictures show what the elevations and worlds might end up looking like.
#
# <div>
#   <table>
#     <tr>
#       <td>
#         <img src="images/elevations.png">
#       </td>
#       <td>
#         <img src="images/uninhabited.png">
#       </td>
#     </tr>
#   </table>
# </div>

# %% [markdown]
# How do we generate worlds? A good first guess is to just randomly sample! This is known as "Value Noise." Here are the steps:
# 1. Create a grid of random values at integer lattice points.
# 2. For any input point (x, y), find the surrounding grid corners.
# 3. Interpolate the corner values
# 4. Clip the noise between 0 and 1, to ensure it is a valid distribution.
#
# For the "interpolation" step, you should use scipy.ndimage.zoom -- you can look at documentation for this function online!

# %%
def value_noise(dim = 75):
    #TODO: Implement Value Noise. First, generate a random 10x10 grid via numpy.random.rand. Then, generate interpolations via scipy.ndimage.zoom with order 5 and the nesscacy sclaing facotr.
    #Interpolation can sometimes add noise greater than 1. Be sure to clip the noise between (0.0, 1.0)
    grid = np.random.rand(10,10)
    scale = dim / 10
    noise = scipy.ndimage.zoom(grid, scale, order=5)
    noise = np.clip(noise, 0.0, 1.0)
    return noise

# %% [markdown]
# This is what your world with value noise looks like!

# %%
noise = value_noise()
ground_elevations = np.array([0.01, 0.075, 0.15, 0.2, 0.3, 0.4, 1.0])
visualize_height_values(ground_elevations, noise, "Value Noise")

# %% [markdown]
# It works, but it seems unrelalistic, with random hotspots and not much water! Can we do better? lot of research has been poured into this, and one method which has been successful is Perlin noise, which you can rea more about on [Wikipedia](https://en.wikipedia.org/wiki/Perlin_noise) and this [blog post](https://flafla2.github.io/2014/08/09/perlinnoise.html). The method is used in both animated movies and Minecraft, and we will use it too in this lab. Below you will find images perlin noise in 1, 2, and 3 dimensions.
#
#
# <div>
#   <table>
#     <tr>
#       <td>
#         <img src="images/perlin_noise.png", width=875px>
#       </td>
#     </tr>
#  </table>
# </div>
#
# We will implement Perlin noise in this section!

# %% [markdown]
# Now, to generate the functions of each frequency, we create a $(l+1) \times (l+1)$ array of unit gradient vectors (kind of like what is shown on the left), where $l$ is the maximum frequency (in the above picture, it is 128). Each square in this grid has 4 gradient vectors on the corner, as shown on the right.
#
# <div>
#   <table>
#     <tr>
#       <td>
#         <img src="images/perlin_gradients.png"style="background-color: white; padding: 10px">
#       </td>
#       <td>
#         <img src="images/perlin_grad_4.png"style="background-color: white; padding: 10px">
#       </td>
#     </tr>
#  </table>
# </div>

# %% [markdown]
# To do this, we must first generates $n$-dimensional gradient vectors with unit length.
#
# There are many different ways we can compute the gradient vector.  Classically, Each gradient vector is computed by independently sampling from $\mathcal{N}(0, I_n)$. For the sake of the lab, please also implement sampling from a ${Exp}(\lambda)$ distribution. Then normalize it to be unit length.
#
# We let $\lambda$ be an input to the function. The possible values of distribution are ["normal", "exponential"]

# %%
def generate_gradient(n, distribution, lam):
    if distribution == "normal":
        g = np.random.normal(loc = 0.0, scale = 1.0, size = n)
        
    elif distribution == "exponential":
        g = np.random.exponential(scale = 1.0, size = n)
    
    else:
        raise ValueError("Distribution must be normal or exponential")

    norm_v = np.linalg.norm(g)
    return g/norm_v

# %% [markdown]
# The cell below, generates the array of gradients for the 2D case as a NumPy array with shape $(l+1, l+1, 2)$.

# %%
def generate_corner_gradients(l, distribution, lam):
    corners = np.array([generate_gradient(2, distribution, lam) for _ in range((l+1) * (l+1))])
    corners = corners.reshape(l+1, l+1, 2)
    return corners

# %% [markdown]
# Now comes the interpolation part. For a general point in $[0, l] \times [0, l]$, we find which square it lies by looking at the floor and ceiling of its x and y coordinates. Then, we compute the dot product of the gradient vector and "delta" vector for each of the 4 corners of the square it lies in. The "delta" vectors for a point in one of the $l \times l$ squares is shown below.
#
# <div>
#   <table>
#     <tr>
#       <td>
#         <img src="images/perlin_dist_4.png", style="background-color: white; padding: 10px">
#       </td>
#     </tr>
#  </table>
# </div>

# %%
def compute_dot_products(gradients, x, y):
    floor_x, floor_y = int(x), int(y)
    ceil_x, ceil_y = floor_x + 1, floor_y + 1
    corner_coords = np.array([[[floor_x, floor_y], [ceil_x, floor_y]],
                              [[floor_x, ceil_y], [ceil_x, ceil_y]]])
    corner_gradients = gradients[floor_y: ceil_y+1, floor_x: ceil_x+1]
    delta = np.array([x, y]) - corner_coords
    return np.sum(corner_gradients * delta, axis=2)

# %% [markdown]
# Now we want to interpolate a value at (x, y) given the values at the 4 corners. It turns out a nice function for doing this involves a degree-5 polynomial.

# %%
def smooth_interp(t, a, b):
    smooth_t = 6*t**5 - 15*t**4 + 10*t**3
    return (1 - smooth_t) * a + smooth_t * b

# %% [markdown]
# Bilinearly interpolate.

# %%
def interpolate(dots, x, y):
    dx = x - np.floor(x)
    dy = y - np.floor(y)
    interp1 = smooth_interp(dx, dots[0, 0], dots[0, 1])
    interp2 = smooth_interp(dx, dots[1, 0], dots[1, 1])
    interp = smooth_interp(dy, interp1, interp2)
    return interp

# %% [markdown]
# Now to put everything together, even though our array of gradients corresponds to a point in $[0, l] \times [0, l]$, each pixel in our 100 x 100 square world will just correspond to a point $[0, 1] \times [0, 1]$. However, we will still use the rest of the array as we will generate the higher frequency functions by mapping a point $x, y \in [0, 1] \times [0, 1]$ to $f \cdot x, f \cdot y \in [0, l] \times [0, l]$, where $f$ is the frequency.

# %%
def generate_world(size=100, l=4, distribution = "normal", lam = 1e-9):
    grad = generate_corner_gradients(2 ** l + 1, distribution, lam)
    units = np.linspace(0, 1, size)
    rescale_factor = (2 ** 0.5)
    grid = np.zeros((size, size))
    for i, x in enumerate(units):
        for j, y in enumerate(units):
            for log_f in range(l):
                f = 2 ** log_f
                amp = 1 / f
                new_x = x * f
                new_y = y * f
                dots = compute_dot_products(grad, new_x, new_y)
                val = interpolate(dots, new_x, new_y)
                rescaled_val = val * rescale_factor
                grid[j][i] += rescaled_val * amp
    grid /= 2 - 2 ** (1 - l)        
    return grid

# %% [markdown]
# You may have to run this cell and the cell below several times to get the world you want.

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 4))
test_worlds = []
fig.suptitle('2D Perlin Noise with Different l')
for l in range(4):
    world = generate_world(l=l+1)
    test_worlds.append(world)
    ax[l].set_title(f'l={l+1}')
    im = ax[l].imshow(world)
    fig.colorbar(im, ax=ax[l], fraction=0.046, pad=0.04)

# %%
fig, ax = plt.subplots(1, 4, figsize=(16, 4))
fig.suptitle('Uninhabited Worlds with Different l')
for l in range(4):
    uninhabited_world = get_uninhabited_world(test_worlds[l])
    ax[l].set_title(f'l={l+1}')
    im = ax[l].imshow(uninhabited_world)

# %% [markdown]
# Use the knobs below to visualize worlds with defined height vectors for the enviorment types.

# %%
import ipywidgets as widgets
from ipywidgets import interact

grid = generate_world()

@interact(ocean=h_o,shallows=h,beach=h,dirt=h,inland=h,mountain=h)
def toggle_ground_heights(ocean=0.01,
                          shallows=0.075,
                          beach=0.15,
                          dirt=0.2,
                          inland=0.3,
                          mountain=0.4,):
    heights = np.array([ocean, shallows, beach, dirt, inland, mountain, 1])
    visualize_height_values(heights, grid, "Perlin Noise")
# Out:
# interactive(children=(FloatSlider(value=0.01, description='ocean', max=0.5, step=0.05), FloatSlider(value=0.07…

# %% [markdown]
# We now might wonder how the type of distribution the gradient is drawn from changes the world! Let's simulate $100$ worlds from $N(0, I_n)$ and $Exp(10^{-9})$, below:

# %%
def plot_multiple_worlds(distribution, lam=None, runs=100, l=4, size=100):
    worlds = []
    for _ in range(runs):
        if distribution == "exponential":
            w = get_uninhabited_world(generate_world(l=l, distribution=distribution, lam=lam, size=size))
        else:
            w = get_uninhabited_world(generate_world(l=l, distribution=distribution, size=size))
        worlds.append(w)

    # Build montage: sqrt(runs) × sqrt(runs) grid
    grid_dim = int(np.sqrt(runs))
    fig, axes = plt.subplots(grid_dim, grid_dim, figsize=(20, 20))
    fig.suptitle(f"{distribution.capitalize()} Worlds ({runs} runs)", fontsize=18)

    for i, ax in enumerate(axes.flat):
        im = ax.imshow(worlds[i], cmap="viridis")
        ax.axis("off")

    plt.tight_layout()
    plt.show()

# Generate 100 runs for each
plot_multiple_worlds("normal", runs=100)
plot_multiple_worlds("exponential", lam=1e-9, runs=100)

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ## TODO: WRITEN QUESTIONS
# Answering below each question:
# 1) Why do you think Perlin Noise works better than Value Noise?
# 2) Do you notice anything different in the type of terrian when you change the gradient generation mechanism from from Normal to Exponential? Are any types missing? Why do you think this is?
# 3) Do you notice anything different in the locations of terrian when you change the gradient generation mechanism from from Normal to Exponential? Do they cluster in a specific location? Why do you think this is?

# %% [markdown]
# Here are some hints for answering the "why" of questions 2 and 3:
#
# - The exponential distribution only outputs positive values, while the normal distribution can output both positve and negative values.
# - The process for generating grids involves taking the dot product between the draws and the direction vector to a given point. Consider what happens if the draws are all positive versus if they are more evenly distributed
# - Recall that we normalize our distribution so that the samples have a norm of 1. If we consider sampling a distribution $X_i$ $n$ times and then normalizing it, we can imagine we have a new distribution defined by: $$\frac{X}{\sqrt{X_1^2 + X_2^2 + \ldots + X_n^2}}$$ If try to plot the empirical this distribution for a $\mathcal{N}(0, I_n)$ and $Exp(1)$ distribution, do you notice anything about the probability of getting zeros? What does this suggest about how big the dot products (and ultimately terrain produced) will be?

# %% [markdown]
# 1. Value noise works by assigning random values to grid points, then interpolates between these values. So the grid patterns appear more "random" and has blocky artifacts. On the contrary, Perlin Noise uses gradient vectors at grid points that "smooths" out the transitions between blocks. By interpolating the influence of the gradients, the patterns you see when using Perlin Noise are more cohesive and smooth compared to value noise
#
# 2. The Exponential Distribution misses out on extreme elevations, and we see that the variance in terrain height is noticably smaller compared to the Normal Distribution. The exponential distribution is always positive (skewed toward 0), and gradients tend to point in similar directions with bias towards moderate elevations. So we see less of Less likely to create steep slopes like mountains and less likely to create deep valleys like oceans. So the Exponential distribution generates a "flatter" world with more uniform, middle-range terrain. Missing the dramatic peaks and valleys that Normal distribution creates.
#
# 3. Yes, when we use the Normal Distribution, we can see that gradients point equally in all directions. But for exponential distributions, we see that the terrain has a "directional tendency", like a systematic drift in one direction that pushes terrain elements to a specific direction. A quick analogy might be that the Normal distribution creates a realistic, spread out terrain like Earth (random plate tectonics), while the exponential distribution creates terrains with systematic patterns, like a tilted plane or directed erosion flow.

# %% [markdown]
# <!-- END QUESTION -->

# %%
import numpy as np
import matplotlib.pyplot as plt

n = 5  # number of dimensions
samples = 10000

# Sample from N(0,1)
normal_samples = np.random.normal(0, 1, (samples, n))
normal_normed = normal_samples / np.linalg.norm(normal_samples, axis=1, keepdims=True)

# Sample from Exp(1)
exp_samples = np.random.exponential(1e-9, (samples, n))
exp_normed = exp_samples / np.linalg.norm(exp_samples, axis=1, keepdims=True)

# --- Create 1x3 subplot ---
fig, axes = plt.subplots(1, 2, figsize=(15, 4), sharey=True)

# |Max coordinate|
axes[0].hist(np.max(np.abs(normal_normed), axis=1), bins=50, alpha=0.6, label='Gaussian', color='blue')
axes[0].hist(np.max(np.abs(exp_normed), axis=1), bins=50, alpha=0.6, label='Exponential', color='orange')
axes[0].set_title('|Max Coordinate|')
axes[0].set_xlabel('Absolute Value')

# |Min coordinate|
axes[1].hist(np.min(np.abs(normal_normed), axis=1), bins=50, alpha=0.6, label='Gaussian', color='blue')
axes[1].hist(np.min(np.abs(exp_normed), axis=1), bins=50, alpha=0.6, label='Exponential', color='orange')
axes[1].set_title('|Min Coordinate|')
axes[1].set_xlabel('Absolute Value')

axes[0].legend()
axes[1].legend()


plt.tight_layout()
plt.show()

# %% [markdown]
# ## Part 2: Bringing Particles to Life
#
# Now that we have our terrain, we can set up our vegetation. The idea is our particles will be able to move around on our 100 x 100 grid, but first, we need to define the state of a particle. For simplicity, we assume the only kind of plant is trees. Each tree has DNA, which is a convex combination of 5 archetypes, each corresponding to an inhabitable land type in our world. (As a side note, a convex combination means a linear combination where the weights are non-negative and add up to 1. Also we consider ocean as not inhabitable for trees.) Here is the correspondence table of the land types and their ideal tree types. For example, a DNA of $[0.05, 0.05, 0.05, 0.8, 0.05]$ will be a tree well suited to live in the Inland environment.
#
#
# <div>
#   <table>
#     <tr>
#       <td>
#         <img src="images/plant_land_table.png", width=400px>
#       </td>
#     </tr>
#   </table>
# </div>

# %% [markdown]
# We will initialize a tree's DNA by sampling each element uniformly from $[0, 1]$ independently and normalizing this vector.
#
# At each time step, a tree may have offpring (seeds) whose DNA will be slightly mutated. The mutation adds a small pertubation vector to the parent's DNA vector. The pertubation vector has each entry sampled uniformly from $[-\sigma, \sigma]$ for some small $\sigma$. Then, we clip each entry of the result to the range $[0, 1]$ and re-normalize.
#
# You do not need to follow the steps above! You are free to design any initialization and mutation scheme that you want to experiment with, but make sure that at each time step, every tree's DNA vector is non-negative and sums to 1.

# %% [markdown]
# **TASK** In the following cell, fill out the functions for generating the initial random DNA as well as generating offspring.
#
# (Note: the tests for this lab are just a sanity check for your code and shouldn't be treated as a solid assessment for algorithmic correctness.)

# %%
def init_random_dna():
    dna = np.random.uniform(0,1,size = 5)
    
    return dna / dna.sum()

# %%
def generate_offspring_dna(parent_dna, sigma):
    perturb = np.random.uniform(-sigma, sigma, size=len(parent_dna))
    child = parent_dna + perturb

    child = np.clip(child, 0, None)

    s = child.sum()


    return child / s

# %% [markdown]
# Now, putting everything together in the tree class.

# %%
class Tree(AbstractTree):

    def initialize_random_dna(self):
        self.dna = init_random_dna()
    
    def generate_offspring(self, sigma):
        offspring_dna = generate_offspring_dna(self.dna, sigma)
        return Tree(dna=offspring_dna)

# %% [markdown]
# Visualize DNA.

# %%
@interact(Shallow=r, Beach=r, Dirt=r, Inland=r, Mountains=r)
def f(Shallow, Beach, Dirt, Inland, Mountains):
    unnormalized_DNA = np.array([Shallow, Beach, Dirt, Inland, Mountains])
    DNA = unnormalized_DNA / np.sum(unnormalized_DNA)
    tree = Tree(DNA)
    visualize_dna(tree)
# Out:
# interactive(children=(FloatSlider(value=0.5, description='Shallow', max=1.0), FloatSlider(value=0.5, descripti…

# %% [markdown]
# Visualize mutations over multiple generations of a tree's DNA. Feel free to play with the variance and see how things change.

# %%
tree = Tree()
var = 0.01
n_steps = 30
for i in range(n_steps):
    clear_output(wait=True)
    fig = visualize_dna(tree)
    if i in [0, n_steps // 2, n_steps - 1]:
        save_fig(fig, f'q2a_frame{i}.png')
    tree = tree.generate_offspring(var)

# %% [markdown]
# ## Part 3: Defining The Mechanics
#
# Now that we have our tree, we can define the mechanics that govern their survival and reproduction.
#
# - Our world will initially be empty, but at each time step, a tree can magically appear in a square with probability `self.life_prob`, perhaps through an animal bringing over its seed. This is be implemented in `simulate_life_creation`.
# - If tree is currently in a square, it survives each time step with some probability. This is implemented in `age_tree`.
# - If it survives, it can then also generate a number of offspring. The number of offspring is sampled independently from a binomial distribution with $n=\text{self.max\_seeds}$ and $p=\text{fitness}$. You can change this distribution to play with too! This is implemented in `generate_offspring`.
# - Finally, if a bunch of trees are on the same square, they will compete for the square because resources are limited! Each tree $t$ on a square $s$ has an "energy" value that is equal to $\exp(\text{s.comp\_constant} \cdot \text{t.fitness})$. Then, each tree on the square wins with probability proportional to its energy value. This is called the **Boltzmann distribution** and is used in economics to model distribution of resources.

# %% [markdown]
# **TASK** Fill out the following function definitions based on the comments in the later code block.

# %%
def can_plant_seed(life_prob):
    # Returns True with probability life_prob, False otherwise
    return random.random() < life_prob

# %%
def can_terminate_tree(survival_prob):
    # Returns True with probability 1 - survival_prob, False otherwise
    return random.random() < 1- survival_prob

# %% [markdown]
# To implement **gen_offspring** and obtain relevant functions, look at **pocket_planet_utils.py** for class definitions and refer to the details in the paragraph above. You're given a Square object in the function definition.

# %%
def gen_offspring(square):

    if not square.contains_tree():
        return []
    
    fitness = square.tree.calc_fitness(square.env_type)
    
    num_seeds = np.random.binomial(square.max_seeds, fitness)
    
    offspring = []
    for _ in range(num_seeds):
        child = square.tree.generate_offspring(square.mutation_var)
        offspring.append(child)
    
    return offspring

# %% [markdown]
# **TASK** Implement the `get_probabilities` function, which takes in a number `comp_constant` and a vector of `fitness` values, and returns a vector of probabilities denoting the probability of each tree winning the competition, as described above by implementing the Boltzmann Distribution.

# %%
def get_probabilities(comp_constant, fitness):
    vals = comp_constant * fitness
    
    energy = np.exp(vals)
    prob = np.clip(0,1,energy/ np.sum(energy))
    
    return prob

# %% [markdown]
# Now, the Square class puts everything together.

# %%
class Square(AbstractSquare):
    
    def simulate_life_creation(self):
        # Calls self.plant_seed(Tree()) with probability self.life_prob
        can_plant_seed(self.life_prob) and self.plant_seed(Tree())
                        
            
    def age_tree(self):
        # Calls self.terminate_tree() with probability 1-survival_prob
        if not self.contains_tree():
            return
        survival_prob = self.tree.calc_fitness(self.env_type)
        can_terminate_tree(survival_prob) and self.terminate_tree()
        

    def generate_offspring(self):
        # Returns a list of offspring as described above
        if not self.contains_tree():
            return []
        # A square will have a tree and other properties that may prove useful.
        return gen_offspring(self)
    
    
    def sample_boltzmann_distribution(self, fitness, return_dist=False):
        # Creates an (np.)array of probabilities corresponding to each tree's energy value, using the formula from the above blurb
        probabilities = get_probabilities(self.comp_constant, fitness)
        
        if return_dist:
            return probabilities
        winner_index = random.choices(np.arange(0, len(fitness)), probabilities)[0]
        return winner_index

# %% [markdown]
# Visualize the evolution of a single tree on our world, and answer the questions below.

# %%
var = 0.03
comp_constant = 1000
    
square = create_secret_square(var, comp_constant, Square)
n_steps = 50
for i in range(n_steps):
    plt.pause(0.1)
    clear_output(wait=True)
    fig = psuedo_env_step(square, Tree)
    if i in [0, n_steps // 2, n_steps - 1]:
        save_fig(fig, f'q3b_frame{i}.png')

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ## TODO: Written Questions
# Based on your investigations, answer the following questions below:
#
# 1) What would you guess is the environment type of the square?
#
#
# 2) How does mutation variance affect the rate of convergence and the behavior once evolution has reached steady state?
#
#
#
# 3) In a rapidly changing environment, would we want a high or low mutation rate? What about in a predictable environment?
#
#
#
# 4) How does the competition constant affect rate of convergence and the behavior once evolution has reached steady state?

# %% [markdown]
# 1. I hypothesize that it's the Dirt environment
# 2. It's like a similar process to the learning rate for gradient descent, if you have a low mutation rate you converge slower to the steady state and less variation when you approach the steady state. On the other hand, with high mutation rate, you converge much faster to the steady state but higher variation near the steady state, making it hard to converge. So a higher mutation rate could lead to unexpected behavior if too much mutation happens from the steady state.
# 3. In a rapidly changing environment, we would want a high mutation rate to adapt faster and converge faster. In a more predictable environment, its better to have a low mutation rate to ensure that you don't overshoot and stray far away from the steady state.
# 4. Low competition constant correlates to lower fitness, so many mediocre trees survive. So we can find high genetic diversity, with a lot of suboptimal DNA. Higher convergence correlates to higher fitness, so only near-optimal trees survive. We can see that there isn't much genetic diversity between the sample spaces, the distribution always ends up near an almost deterministic selection.

# %% [markdown]
# <!-- END QUESTION -->
#
# ## Q4 Bringing It All Together
#
# You're almost done! All that is left is to make our particles be able to move across squares.
#
# - In `simulate_movement`, we want to be able to move a particle from position $i, j$.  To do this, we'll generate`new_coord` as follows:
#     1. Start with `coord`, a 2-element vector denoting the particle's current position.
#     2. Perturb each coordinate with i.i.d $\text{Normal}(0, \text{var})$ noise.
#     3. Clip each coordinate to be within the range `[min_val, max_val]`.
#     4. Round each coordinate to the nearest integer.
#  <!-- from $\text{Normal}([i,j], var)$, (where $[i, j]$ is a 2-element vector), then clip to `[min_val, max_val]`, and finally round to the nearest integer. -->
# - In `spread_seeds`, we'll get new positions for a seeds at $i, j$ by setting the variance for `simulate_movement`. If a square is an ocean, set variance to be `self.waves_var`. Otherwise, set it to be `self.wind_var`.

# %%
def get_new_coord(coord, var, min_val, max_val):
    pertub = np.random.normal(0,var)
    new_coord = np.clip(coord + pertub,min_val,max_val)
    new_coord = np.rint(new_coord).astype(int)
    
    return new_coord

# %% [markdown]
# Finally, the World implementation.

# %%
class World(AbstractWorld):
    def simulate_movement(self, i, j, var):
        coord = np.array([i, j])
        min_val, max_val = 0, self.dim - 1
        
        new_coord = get_new_coord(coord, var, min_val, max_val)
        
        return new_coord[0], new_coord[1]
    
    def spread_seeds(self, i, j):
        square = self.world[i][j]
        trees = square.get_seeds()
        
        if square.is_ocean():
            var = self.waves_var
        else:
            var = self.wind_var
            
        for tree in trees:
            x, y = self.simulate_movement(i, j, var)
            self.world[x][y].plant_seed(tree)

# %% [markdown]
# ## Congratulations!
#
# You're free! We hope you've enjoyed this evolutionary journey. We highly recommend tinkering with the hyperparameters. After putting in all this work, you might as well get some fun out of it. If you find any cool properties, feel free to write about it below!

# %%
world = World(generate_world,
              Square,
              dim=100,
              mutation_var=0.03,
              comp_constant=100,
              wind_var=2,
              waves_var=5)

n_steps = 150
for i in range(n_steps):
    fig = world.env_step()
    if i in [0, n_steps // 2, n_steps - 1]:
        save_fig(fig, f'q4_frame{i}.png')

# %% [markdown]
# ## TODO: Written Questions

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
#  1. When life initially starts to spread across the map, the fitness curve is extremely volatile, but eventually it smooths out. Why is this?
#  2. You might notice that the Coverage progression curve tends to match a sigmoid curve. Give a conjecture as to why this might be.

# %% [markdown]
# 1. Initially, early trees have random and un-optimized DNA. Some happen to land in matching environments (high fitness), others in mismatched ones (low fitness). So there will be a lot of variance between trees that secure the square before it stabilizes, which leads to drastic affects to the fitness score.
# 2. I'm hypothesizing that the sigmoid curve comes from the tree spread having a logistic growth pattern. Our simulation starts off with few trees, spreading slowly, but soon the stabilized trees generate many seeds (binomial with n=max_seeds) that lead to exponential growth. Over time, many of the squares find the optimal trees and growth slows. This follows a similar dynamic where the rate of change for coverage is proportional to the current coverage * (1- coverage) (the squares left) which might explain the sigmoid-shape (logistic equation).

# %% [markdown]
# <!-- END QUESTION -->
#
# ## Submission
#
# Congratulations on completing the lab! Run all the cells in this notebook, save it, and then upload the entire notebook as a pdf to gradescope.

# %% [markdown]
# ## References
#
# 1. https://en.wikipedia.org/wiki/Perlin_noise
# 1. https://flafla2.github.io/2014/08/09/perlinnoise.html
# 1. https://gamedev.stackexchange.com/questions/23625/how-do-you-generate-tileable-perlin-noise
